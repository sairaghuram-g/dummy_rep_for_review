# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
z = [*range(1, 31)]
num = np.exp(z)

plt.plot(z, num, color='blue',
    marker='o',
    linestyle='-')
plt.xlabel('z')
plt.ylabel('softmax')
plt.title('$e$')
plt.show()

# %%
z = [1, 2, 3]
num = np.exp(z)
den = np.sum(np.exp(z))
sigma = num/den

print(sigma)
print(np.sum(sigma))

# %%
z = np.random.randint(-5, high=15, size=25)
num = np.exp(z)
den = np.sum(np.exp(z))
sigma = num/den

print(sigma)
print(np.sum(sigma))
# Out:
# [1.37864872e-01 1.70138769e-05 1.37864872e-01 4.21731843e-08
#  2.30257784e-06 4.21731843e-08 4.21731843e-08 3.41732852e-04
#  2.52508321e-03 1.37864872e-01 6.25905551e-06 1.14638600e-07
#  6.86388781e-03 6.86388781e-03 1.55146475e-08 1.25716491e-04
#  3.41732852e-04 3.74755577e-01 5.70751984e-09 1.37864872e-01
#  3.11620025e-07 2.52508321e-03 5.07176521e-02 2.52508321e-03
#  9.28926201e-04]
# 1.0

# %%
idx = np.argsort(z)

z_sorted = z[idx]
sigma_sorted = sigma[idx]

plt.plot(z_sorted, sigma_sorted, color='blue',
    marker='o')
plt.xlabel('z')
plt.ylabel('softmax')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()

# %%
plt.plot(z, sigma, 'ko')
plt.xlabel('z')
plt.ylabel('softmax')
plt.yscale('log')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()

# %% [markdown]
# If we see, a softmax function is basically a linear regression function on a logarithmic scale

# %% [markdown]
# # Using pytorch

# %%
softfun = nn.Softmax(dim=0)

sigmaT = softfun(torch.Tensor(z))

print(sigmaT)
# Out:
# tensor([4.3660e-05, 2.9418e-07, 5.3881e-09, 8.7693e-04, 2.9418e-07, 6.4797e-03,
#         5.9087e-06, 2.1737e-06, 9.6167e-01, 6.4797e-03, 2.9418e-07, 3.9813e-08,
#         5.3881e-09, 7.9966e-07, 6.4797e-03, 1.7614e-02, 1.4646e-08, 7.9966e-07,
#         3.2261e-04, 2.1737e-06, 3.9813e-08, 1.0822e-07, 7.9966e-07, 1.6062e-05,
#         1.0822e-07])
