# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(.0001, 1, 200)
logx = np.log(x)

fig = plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size':15})
plt.plot(x,logx,markerfacecolor='w')
plt.xlabel('x')
plt.ylabel('log(x)')
plt.show()

# %%
x = np.linspace(.1, 1, 20)
logx = np.log(x)
expx = np.exp(x)

plt.plot(x,x,color=[.8,.8,.8])
plt.plot(x, logx, color='blue', marker='x', linestyle='-')
plt.plot(x, expx, color='green', marker='o', linestyle='-')
plt.plot(x,np.exp(logx),'o',markersize=8)
plt.plot(x,np.log(expx),'x',markersize=8)
plt.xlabel('x')
plt.ylabel('f(g(x))')
plt.legend(['unity', 'log(x)', 'exp(x)', 'exp(log(x))', 'log(exp(x))'])
plt.show()
